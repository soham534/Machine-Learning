# %% [markdown]
# <a href="https://colab.research.google.com/github/soham534/Machine-Learning/blob/main/Predicting_the_house_price(Multiple_regression)_By_Soham_Bundela.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.datasets import fetch_california_housing # Updated import

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Problem Statement
# * You have been given a dataset that describes the houses in California. Now, based on the given features, you have to predict the house price.

# %% [markdown]
# # Creating the DataFrame

# %%
california = fetch_california_housing()
df = pd.DataFrame(california.data)

# %% [markdown]
# # EDA- Exploratory Data Analysis

# %%
df.head()
# Out:
#         0     1         2         3       4         5      6       7
# 0  8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1  8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2  7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3  5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4  3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25

# %% [markdown]
# * Adding Columns

# %%
df.columns = california.feature_names

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %% [markdown]
# # Adding the target column into the DataFrame

# %%
df['PRICE'] = california.target

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  PRICE
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
df.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  PRICE
# 20635    -121.09  0.781
# 20636    -121.21  0.771
# 20637    -121.22  0.923
# 20638    -121.32  0.847
# 20639    -121.24  0.894

# %%
df.shape
# Out:
# (20640, 9)

# %%
df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'PRICE'],
#       dtype='object')

# %%
df.dtypes
# Out:
# MedInc        float64
# HouseAge      float64
# AveRooms      float64
# AveBedrms     float64
# Population    float64
# AveOccup      float64
# Latitude      float64
# Longitude     float64
# PRICE         float64
# dtype: object

# %%
df.nunique()
# Out:
# MedInc        12928
# HouseAge         52
# AveRooms      19392
# AveBedrms     14233
# Population     3888
# AveOccup      18841
# Latitude        862
# Longitude       844
# PRICE          3842
# dtype: int64

# %%
df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# PRICE         0
# dtype: int64

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         PRICE
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
df.corr
# Out:
# <bound method DataFrame.corr of        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data=df.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
sns.pairplot(df,size=2.5)
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# BoxPlot
plt.figure(figsize=(60,60))
df.boxplot()
# Out:
# <Axes: >

# %%
# Minimum Price
df["PRICE"].min()
# Out:
# 0.14999

# %%
# Maximum Price
df["PRICE"].max()
# Out:
# 5.00001

# %%
# Standard Deviation
df["PRICE"].std()
# Out:
# 1.1539561587441483

# %% [markdown]
# # Export the Dataset

# %%
df.to_csv('california.csv',)

# %% [markdown]
# # Machine Learning - Linear Regression

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  PRICE
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
x = df.drop("PRICE",axis=1)
y = df.PRICE

# x=california.data
# y=california.target

# %%
x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: PRICE, Length: 20640, dtype: float64

# %% [markdown]
# * Converting in a 2-D array
# (For regression)

# %%
x.ndim
# Out:
# 2

# %%
x = np.array(df.drop("PRICE",axis=1))
y = np.array(df.PRICE)

# %%
x
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]])

# %%
y
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %% [markdown]
# # Splitting the data

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
len(x_train)
# Out:
# 16512

# %%
len(y_train)
# Out:
# 16512

# %%
len(x_test)
# Out:
# 4128

# %%
len(x_test)
# Out:
# 4128

# %% [markdown]
# # Choosing the model

# %%
model = LinearRegression()

# %% [markdown]
# # Fitting/Train the model

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Intercept value
model.intercept_
# Out:
# np.float64(-37.02327770606391)

# %%
# Coefficient value
model.coef_
# Out:
# array([ 4.48674910e-01,  9.72425752e-03, -1.23323343e-01,  7.83144907e-01,
#        -2.02962058e-06, -3.52631849e-03, -4.19792487e-01, -4.33708065e-01])

# %% [markdown]
# # Prediction

# %%
y_test
# Out:
# array([0.477  , 0.458  , 5.00001, ..., 5.00001, 0.723  , 1.515  ])

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([0.71912284, 1.76401657, 2.70965883, ..., 4.46877017, 1.18751119,
#        2.00940251])

# %% [markdown]
# # Testing the model performance

# %%
model.score(x_test,y_test)
# Out:
# 0.5757877060324524

# %%
# R square
r2_score(y_test,y_pred)
# Out:
# 0.5757877060324524

# %%
# Adjusted R squared
adj_r2 = 1 - (1-r2_score(y_test,y_pred)) * (len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
adj_r2
# Out:
# 0.5749637928613575

# %%
# MSE
mean_squared_error(y_test,y_pred)
# Out:
# 0.5558915986952422

# %%
# MAE
mean_absolute_error(y_test,y_pred)
# Out:
# 0.533200130495698

# %%
# RMSE
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# np.float64(0.7455813830127749)

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.grid()
plt.plot([min(y_test),max(y_test)],[min(y_pred),max(y_pred)],color='red')
plt.title("Actual Prices vs Predicted Prices")
plt.show(plt.figure(figsize=(6,6)))

# %% [markdown]
# # Klib library
#
# * Pypi: https://pypi.org/project/klib/

# %%
# !pip install klib

# %%
import klib
import pandas as pd
from sklearn.datasets import load_diabetes,load_iris

# %%
df = pd.read_csv("https://raw.githubusercontent.com/agconti/kaggle-titanic/refs/heads/master/data/train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# klib.describe - functions for visualizing datasets
klib.cat_plot(df) # returns a visualization of the number and frequency of categorical features
# Out:
# GridSpec(6, 5)

# %%
klib.corr_mat(df) # returns a color-encoded correlation matrix
# Out:
# /usr/local/lib/python3.11/dist-packages/klib/describe.py:275: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   return corr.style.applymap(color_negative_red).format("{:.2f}", na_rep="-")
# <style type="text/css">
# #T_8101c_row0_col0, #T_8101c_row0_col3, #T_8101c_row0_col6, #T_8101c_row1_col1, #T_8101c_row1_col5, #T_8101c_row1_col6, #T_8101c_row2_col2, #T_8101c_row2_col4, #T_8101c_row2_col5, #T_8101c_row3_col0, #T_8101c_row3_col3, #T_8101c_row3_col6, #T_8101c_row4_col2, #T_8101c_row4_col4, #T_8101c_row4_col5, #T_8101c_row4_col6, #T_8101c_row5_col1, #T_8101c_row5_col2, #T_8101c_row5_col4, #T_8101c_row5_col5, #T_8101c_row5_col6, #T_8101c_row6_col0, #T_8101c_row6_col1, #T_8101c_row6_col3, #T_8101c_row6_col4, #T_8101c_row6_col5, #T_8101c_row6_col6 {
#   color: None;
# }
# ...

# %%
klib.corr_plot(df) # returns a color-encoded heatmap, ideal for correlations
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df) # returns a distribution plot for every numeric feature
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
klib.missingval_plot(df) # returns a figure containing information about missing values
# Out:
# GridSpec(6, 6)

# %%
# klib.clean - functions for cleaning datasets
- klib.data_cleaning(df) # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
- klib.clean_column_names(df) # cleans and standardizes column names, also called inside data_cleaning()
- klib.convert_datatypes(df) # converts existing to more efficient dtypes, also called inside data_cleaning()
- klib.drop_missing(df) # drops missing values, also called in data_cleaning()
- klib.mv_col_handling(df) # drops features with high ratio of missing vals based on informational content
- klib.pool_duplicate_subsets(df) # pools subset of cols based on duplicates with min. loss of information
# Out:
# Shape of cleaned data: (891, 12) - Remaining NAs: 866
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.05 MB (-62.5%)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-59-741996728.py in <cell line: 0>()
#       1 # klib.clean - functions for cleaning datasets
# ----> 2 - klib.data_cleaning(df) # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
#       3 - klib.clean_column_names(df) # cleans and standardizes column names, also called inside data_cleaning()
#       4 - klib.convert_datatypes(df) # converts existing to more efficient dtypes, also called inside data_cleaning()
#       5 - klib.drop_missing(df) # drops missing values, also called in data_cleaning()
#
# ...

# %% [markdown]
# * Hyperparameter Tuning
